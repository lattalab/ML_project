# %%
import pandas as pd
import glob

# 1. 獲取所有CSV檔案的檔案路徑
# glob找尋符合的檔案
file_paths = glob.glob('./*.csv')

# 2. 讀取所有CSV檔案並存儲為DataFrame列表
dataframes = [pd.read_csv(file) for file in file_paths]

# %%
import numpy as np
from scipy.stats import levene
from scipy.stats import ttest_ind

# 獲取所有標籤
for df in dataframes:
    labels = df['Label'].unique()   # [True, False]
    # 分成真實(True)和合成(False)兩類
    real_label = df[df['Label'] == labels[0]]
    fake_label = df[df['Label'] == labels[1]]

    for col in df.columns[1:-1]:
        statistic, p_value = levene(real_label[col], fake_label[col])
        if p_value > 0.05:  # 變異數沒有顯著差異
            # 執行t檢定
            stat, p_val = ttest_ind(real_label[col], fake_label[col], equal_var=True, alternative='two-sided')
            if p_val < 0.05:    # 顯著差異
                print('Column:', f'=={col}==', end=' , ')
                print('統計量：%.2f'%stat, end=' , ')
                print('p-value:%.2f'%p_val, end=', ')
                print("具有顯著差異")
# Out:
# Column: ==Mel_Spectrogram_6== , 統計量：-45.33 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_13== , 統計量：-27.95 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_14== , 統計量：-32.71 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_19== , 統計量：-20.47 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_24== , 統計量：-9.22 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_25== , 統計量：-7.60 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_26== , 統計量：-6.68 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_27== , 統計量：-6.27 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_28== , 統計量：-5.78 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_29== , 統計量：-4.48 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_30== , 統計量：-4.36 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_31== , 統計量：-5.17 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_37== , 統計量：-2.39 , p-value:0.02, 具有顯著差異
# Column: ==Mel_Spectrogram_59== , 統計量：2.53 , p-value:0.01, 具有顯著差異
# Column: ==Mel_Spectrogram_62== , 統計量：2.72 , p-value:0.01, 具有顯著差異
# Column: ==Mel_Spectrogram_63== , 統計量：2.73 , p-value:0.01, 具有顯著差異
# Column: ==Mel_Spectrogram_64== , 統計量：2.48 , p-value:0.01, 具有顯著差異
# Column: ==Mel_Spectrogram_65== , 統計量：2.70 , p-value:0.01, 具有顯著差異
# Column: ==Mel_Spectrogram_77== , 統計量：-6.41 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_83== , 統計量：-4.78 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_84== , 統計量：-5.73 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_85== , 統計量：-7.91 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_86== , 統計量：-8.14 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_87== , 統計量：-9.53 , p-value:0.00, 具有顯著差異
# Column: ==mfcc_1== , 統計量：-19.60 , p-value:0.00, 具有顯著差異
# Column: ==mfcc_6== , 統計量：21.94 , p-value:0.00, 具有顯著差異
# Column: ==mfcc_8== , 統計量：23.86 , p-value:0.00, 具有顯著差異
# Column: ==RMS_1== , 統計量：-21.46 , p-value:0.00, 具有顯著差異
# Column: ==ZCR_1== , 統計量：-31.23 , p-value:0.00, 具有顯著差異

# %%
import numpy as np
from scipy.stats import levene
from scipy.stats import ttest_ind

# 獲取所有標籤
for df in dataframes:
    labels = df['Label'].unique()   # [True, False]
    # 分成真實(True)和合成(False)兩類
    real_label = df[df['Label'] == labels[0]]
    fake_label = df[df['Label'] == labels[1]]

    for col in df.columns[1:-1]:
        statistic, p_value = levene(real_label[col], fake_label[col])
        if p_value < 0.05:  # 變異數有顯著差異
            # 執行Welch's t-test
            stat, p_val = ttest_ind(real_label[col], fake_label[col], equal_var=False, alternative='two-sided')
            if p_val < 0.05:    # 顯著差異
                print('Column:', f'=={col}==', end=' , ')
                print('統計量：%.2f'%stat, end=' , ')
                print('p-value:%.2f'%p_val, end=', ')
                print("具有顯著差異")
# Out:
# Column: ==Chroma_1== , 統計量：13.28 , p-value:0.00, 具有顯著差異
# Column: ==Chroma_2== , 統計量：13.89 , p-value:0.00, 具有顯著差異
# Column: ==Chroma_3== , 統計量：17.42 , p-value:0.00, 具有顯著差異
# Column: ==Chroma_4== , 統計量：17.98 , p-value:0.00, 具有顯著差異
# Column: ==Chroma_5== , 統計量：11.83 , p-value:0.00, 具有顯著差異
# Column: ==Chroma_7== , 統計量：2.40 , p-value:0.02, 具有顯著差異
# Column: ==Chroma_11== , 統計量：3.13 , p-value:0.00, 具有顯著差異
# Column: ==Chroma_12== , 統計量：10.65 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_1== , 統計量：55.95 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_2== , 統計量：7.12 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_3== , 統計量：-19.70 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_4== , 統計量：-29.35 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_5== , 統計量：-37.47 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_7== , 統計量：-43.14 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_8== , 統計量：-32.12 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_9== , 統計量：-23.65 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_10== , 統計量：-18.04 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_11== , 統計量：-17.84 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_12== , 統計量：-21.01 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_15== , 統計量：-33.35 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_16== , 統計量：-32.19 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_17== , 統計量：-28.62 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_18== , 統計量：-25.16 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_20== , 統計量：-18.16 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_21== , 統計量：-16.66 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_22== , 統計量：-12.96 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_23== , 統計量：-10.10 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_32== , 統計量：-4.12 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_33== , 統計量：-2.95 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_34== , 統計量：-2.66 , p-value:0.01, 具有顯著差異
# Column: ==Mel_Spectrogram_35== , 統計量：-2.41 , p-value:0.02, 具有顯著差異
# Column: ==Mel_Spectrogram_36== , 統計量：-2.64 , p-value:0.01, 具有顯著差異
# Column: ==Mel_Spectrogram_54== , 統計量：2.16 , p-value:0.03, 具有顯著差異
# Column: ==Mel_Spectrogram_57== , 統計量：1.99 , p-value:0.05, 具有顯著差異
# Column: ==Mel_Spectrogram_67== , 統計量：-2.41 , p-value:0.02, 具有顯著差異
# Column: ==Mel_Spectrogram_68== , 統計量：-2.98 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_69== , 統計量：-3.79 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_70== , 統計量：-3.02 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_71== , 統計量：-3.92 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_72== , 統計量：-5.00 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_73== , 統計量：-4.10 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_74== , 統計量：-3.93 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_75== , 統計量：-6.57 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_76== , 統計量：-6.41 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_78== , 統計量：-6.23 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_79== , 統計量：-3.47 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_81== , 統計量：-2.32 , p-value:0.02, 具有顯著差異
# Column: ==Mel_Spectrogram_82== , 統計量：-3.80 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_88== , 統計量：-8.84 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_89== , 統計量：-7.67 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_90== , 統計量：-8.59 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_91== , 統計量：-9.75 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_92== , 統計量：-11.06 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_93== , 統計量：-13.21 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_94== , 統計量：-13.88 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_95== , 統計量：-12.64 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_96== , 統計量：-12.75 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_97== , 統計量：-11.39 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_98== , 統計量：-12.23 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_99== , 統計量：-13.00 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_100== , 統計量：-12.85 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_101== , 統計量：-13.41 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_102== , 統計量：-13.36 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_103== , 統計量：-13.49 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_104== , 統計量：-16.25 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_105== , 統計量：-20.05 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_106== , 統計量：-20.36 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_107== , 統計量：-20.96 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_108== , 統計量：-21.79 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_109== , 統計量：-21.36 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_110== , 統計量：-20.14 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_111== , 統計量：-19.18 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_112== , 統計量：-16.90 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_113== , 統計量：-15.15 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_114== , 統計量：-15.10 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_115== , 統計量：-20.22 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_116== , 統計量：-41.16 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_117== , 統計量：-54.83 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_118== , 統計量：-53.53 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_119== , 統計量：-54.12 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_120== , 統計量：-56.36 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_121== , 統計量：-55.71 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_122== , 統計量：-57.02 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_123== , 統計量：-55.21 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_124== , 統計量：-53.38 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_125== , 統計量：-50.16 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_126== , 統計量：-48.65 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_127== , 統計量：-39.36 , p-value:0.00, 具有顯著差異
# Column: ==Mel_Spectrogram_128== , 統計量：-24.81 , p-value:0.00, 具有顯著差異
# Column: ==mfcc_2== , 統計量：18.57 , p-value:0.00, 具有顯著差異
# Column: ==mfcc_3== , 統計量：-58.09 , p-value:0.00, 具有顯著差異
# Column: ==mfcc_4== , 統計量：6.93 , p-value:0.00, 具有顯著差異
# Column: ==mfcc_5== , 統計量：-33.44 , p-value:0.00, 具有顯著差異
# Column: ==mfcc_7== , 統計量：-7.55 , p-value:0.00, 具有顯著差異
# Column: ==mfcc_9== , 統計量：13.06 , p-value:0.00, 具有顯著差異
# Column: ==mfcc_10== , 統計量：23.81 , p-value:0.00, 具有顯著差異
# Column: ==mfcc_11== , 統計量：29.64 , p-value:0.00, 具有顯著差異
# Column: ==mfcc_13== , 統計量：47.05 , p-value:0.00, 具有顯著差異
# Column: ==spectral_cendtroid_1== , 統計量：-31.74 , p-value:0.00, 具有顯著差異
# Column: ==tonnetz_1== , 統計量：-2.24 , p-value:0.03, 具有顯著差異
# Column: ==tonnetz_4== , 統計量：5.75 , p-value:0.00, 具有顯著差異
# Column: ==tonnetz_5== , 統計量：7.94 , p-value:0.00, 具有顯著差異
# Column: ==tonnetz_6== , 統計量：8.22 , p-value:0.00, 具有顯著差異
