# %%
import pandas as pd
import glob

# 1. 獲取所有CSV檔案的檔案路徑
# glob找尋符合的檔案
file_paths = glob.glob('./*.csv')

# 2. 讀取所有CSV檔案並存儲為DataFrame列表
dataframes = [pd.read_csv(file) for file in file_paths]

# %%
# 蒐集每個特徵的np.array
real = []; fake = []; feature_names = []
# 找遍所有的dataframe
for df in dataframes:
    labels = df['Label'].unique()   # [True, False]
    # 分成真實(True)和合成(False)兩類
    real_label = df[df['Label'] == labels[0]]
    fake_label = df[df['Label'] == labels[1]]

    columns = []    # 蒐集特徵
    for col in df.columns[1:-1]:
        if '_' in col:
            columns.append(col)
    
    name = columns[0].split('_')[0]
    feature_names.append(name)
    real.append(real_label[columns].values)
    fake.append(fake_label[columns].values)

print(feature_names)
# Out:
# ['Chroma', 'mel-spec', 'MFCC', 'RMS', 'centroid', 'tonnetz', 'ZCR']

# %%
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import numpy as np

# 初始化 t-SNE 模型
tsne = TSNE(n_components=2, random_state=42)
count =0
# 將數據降維
for real_data, fake_data, name in zip(real, fake, feature_names):
    X = np.vstack((real_data, fake_data))   # 按列合併
    y = np.hstack((np.ones(real_data.shape[0]), np.zeros(fake_data.shape[0])))
    if X.shape[1] < 2:  # 如果特徵數小於2，則不進行降維
        continue
    else:
        X_embedded = tsne.fit_transform(X)

    # 可視化結果
    fig = plt.figure(figsize=(10, 7))
    plt.scatter(X_embedded[y == 1, 0], X_embedded[y == 1, 1], label='Real Samples', alpha=0.6)
    plt.scatter(X_embedded[y == 0, 0], X_embedded[y == 0, 1], label='Synthetic Samples', alpha=0.6)
    plt.legend()
    plt.title(f't-SNE visualization of Real and Synthetic Samples of {name}')
    plt.xlabel('t-SNE Component 1')
    plt.ylabel('t-SNE Component 2')
    plt.show()
    count +=1
# Out:
# d:\ancode\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# d:\ancode\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# d:\ancode\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# d:\ancode\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# d:\ancode\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# d:\ancode\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# d:\ancode\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# d:\ancode\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %% [markdown]
# * 組合兩個一維數據看散佈圖看看

# %%
one_dim = ['RMS.csv', 'sc.csv', 'zcr.csv']

# %%
dataframes = [pd.read_csv(file) for file in one_dim]
df = pd.concat(dataframes, axis=1)
# 保留每個欄位名的第一次出現
df = df.loc[:, ~df.columns.duplicated()]
# 顯示結果
df.head()
# Out:
#                    Audio_name     RMS_1  Label   centroid_1     ZCR_1
# 0  bonafide_LA_D_7718079.flac  0.092310   True  1852.384929  0.104444
# 1  bonafide_LA_T_5630619.flac  0.086740   True  1908.336268  0.069537
# 2  bonafide_LA_E_7483475.flac  0.042025   True  1756.788951  0.133155
# 3  bonafide_LA_E_8696873.flac  0.054220   True  1904.918901  0.064446
# 4  bonafide_LA_D_8073490.flac  0.065852   True  1849.660695  0.082628

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# hue: 根據Label的值對數據進行分組

sns.pairplot(df, hue='Label')
plt.show()
